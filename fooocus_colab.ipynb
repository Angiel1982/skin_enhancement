# %%
# 1. Install pygit2 first (as you did)
# !pip install pygit2==1.15.1

# 2. Clone Fooocus
# %cd /content
# !git clone https://github.com/lllyasviel/Fooocus.git
# %cd /content/Fooocus

# 3. FIX THE DEPENDENCY ISSUE BEFORE RUNNING
# Uninstall conflicting cupy and numpy, then reinstall compatible versions
# !pip uninstall -y cupy
# !pip install numpy==1.26.4
# !pip install cupy-cuda12x  # Use cuda11x if your CUDA version is 11.x

# 4. Now run Fooocus
# !python entry_with_update.py --share --always-high-vram
